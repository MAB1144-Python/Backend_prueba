# %%
#"login for make token"
import requests
import json

"""    'host': '23.102.103.53:5200',
    'user': 'bmontenegroprueba',
    'password': 'bmontenegroprueba',
    'database': 'BrayanMontenegro'"""
url = "http://23.102.103.53:5200/api/Login"
param = {
    "userName":"user",
    "password":"1234"
}
response = requests.post(url, json=param).json()
token = response['token']
print(token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6InVzZXIiLCJqdGkiOiI5OWYxYzFiZi1mNGJiLTQ1NWItODc1NS01ZTcyMjZlMWRlNjEiLCJleHAiOjE2ODU3NjM5OTR9.PmQFTq26MR2jEsw4bXmUIaBHvSijZ5wWnd6P2ZLWXKI

# %%
import pandas as pd
import datetime
Headers = { 
        'accept': 'application/json',
        "Authorization" : "Bearer "+token,
        'Access-Control-Allow-Origin': '*'
     }

url_conteo_vehiculos = "http://23.102.103.53:5200/api/ConteoVehiculos/2021-12-25"
#Fecha con el día a consultar con formato “YYYY-MM-DD”.
requests.get(url_conteo_vehiculos, headers=Headers)
# Out:
# <Response [204]>

# %%
import pandas as pd
import datetime
Headers = { 
        'accept': 'application/json',
        "Authorization" : "Bearer "+token,
        'Access-Control-Allow-Origin': '*'
     }

url_conteo_vehiculos = "http://23.102.103.53:5200/api/ConteoVehiculos/"
#Fecha con el día a consultar con formato “YYYY-MM-DD”.
ahora = datetime.datetime(2021, 8, 1)
fecha = ahora.strftime("%Y-%m-%d")
resp_st = '200'
while '200' in str(resp_st):
        resp_st = requests.get(url_conteo_vehiculos+ahora.strftime("%Y-%m-%d"), headers=Headers)
        response_cv = resp_st.json()
        import pandas as pd
        print(resp_st,ahora)
        #df = pd.DataFrame(response_cv)
        df_dia["fecha"] = ahora.strftime("%Y-%m-%d")
        df1 = pd.concat([df, pd.DataFrame(response_cv)], ignore_index=True, sort=False)
        #actualiza fecha
        ahora = ahora+ datetime.timedelta(days=1)
print(df1)

# %%
df.to_csv('route_ConteoVehiculos.csv')

# %%
import pandas as pd
Headers = { 
        'accept': 'application/json',
        "Authorization" : "Bearer "+token,
        'Access-Control-Allow-Origin': '*'
     }

ahora = datetime.datetime(2021, 8, 1)+ datetime.timedelta(days=1) #datetime.strptime("2021-08-01", '%y-%m-%d')
fecha = ahora.strftime("%Y-%m-%d")
url_conteo_vehiculos = "http://23.102.103.53:5200/api/RecaudoVehiculos/"
#Fecha con el día a consultar con formato “YYYY-MM-DD”.
response_cv = requests.get(url_conteo_vehiculos+ahora.strftime("%Y-%m-%d"), headers=Headers).json()
print(response_cv)
import pandas as pd
print(type(response_cv))
df = pd.DataFrame(response_cv)
print(df)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[84], line 12
#      10 url_conteo_vehiculos = "http://23.102.103.53:5200/api/RecaudoVehiculos/"
#      11 #Fecha con el día a consultar con formato “YYYY-MM-DD”.
# ---> 12 response_cv = requests.get(url_conteo_vehiculos+ahora.strftime("%Y-%m-%d"), headers=Headers).json()
#      13 print(response_cv)
#      14 import pandas as pd
#
# File /opt/homebrew/lib/python3.11/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import pandas as pd
import datetime
Headers = { 
        'accept': 'application/json',
        "Authorization" : "Bearer "+token,
        'Access-Control-Allow-Origin': '*'
     }

url_conteo_vehiculos = "http://23.102.103.53:5200/api/RecaudoVehiculos/"
#Fecha con el día a consultar con formato “YYYY-MM-DD”.
ahora = datetime.datetime(2021, 8, 1)
fecha = ahora.strftime("%Y-%m-%d")
resp_st = '200'
df = pd.DataFrame()
while '200' in str(resp_st):
        resp_st = requests.get(url_conteo_vehiculos+ahora.strftime("%Y-%m-%d"), headers=Headers)
        response_cv = resp_st.json()
        import pandas as pd
        print(resp_st,ahora)
        df_dia = pd.DataFrame(response_cv)
        df_dia["fecha"] = ahora.strftime("%Y-%m-%d")
        df = pd.concat([df, df_dia], ignore_index=True, sort=False)
        #actualiza fecha
        ahora = ahora+ datetime.timedelta(days=1)
print(df)
# Out:
# <Response [200]> 2021-08-01 00:00:00
# <Response [200]> 2021-08-02 00:00:00
# <Response [200]> 2021-08-03 00:00:00
# <Response [200]> 2021-08-04 00:00:00
# <Response [200]> 2021-08-05 00:00:00
# <Response [200]> 2021-08-06 00:00:00
# <Response [200]> 2021-08-07 00:00:00
# <Response [200]> 2021-08-08 00:00:00
# <Response [200]> 2021-08-09 00:00:00
# <Response [200]> 2021-08-10 00:00:00
# <Response [200]> 2021-08-11 00:00:00
# <Response [200]> 2021-08-12 00:00:00
# <Response [200]> 2021-08-13 00:00:00
# <Response [200]> 2021-08-14 00:00:00
# <Response [200]> 2021-08-15 00:00:00
# <Response [200]> 2021-08-16 00:00:00
# <Response [200]> 2021-08-17 00:00:00
# <Response [200]> 2021-08-18 00:00:00
# <Response [200]> 2021-08-19 00:00:00
# <Response [200]> 2021-08-20 00:00:00
# <Response [200]> 2021-08-21 00:00:00
# <Response [200]> 2021-08-22 00:00:00
# <Response [200]> 2021-08-23 00:00:00
# <Response [200]> 2021-08-24 00:00:00
# <Response [200]> 2021-08-25 00:00:00
# <Response [200]> 2021-08-26 00:00:00
# <Response [200]> 2021-08-27 00:00:00
# <Response [200]> 2021-08-28 00:00:00
# <Response [200]> 2021-08-29 00:00:00
# <Response [200]> 2021-08-30 00:00:00
# <Response [200]> 2021-08-31 00:00:00
# <Response [200]> 2021-09-01 00:00:00
# <Response [200]> 2021-09-02 00:00:00
# <Response [200]> 2021-09-03 00:00:00
# <Response [200]> 2021-09-04 00:00:00
# <Response [200]> 2021-09-05 00:00:00
# <Response [200]> 2021-09-06 00:00:00
# <Response [200]> 2021-09-07 00:00:00
# <Response [200]> 2021-09-08 00:00:00
# <Response [200]> 2021-09-09 00:00:00
# <Response [200]> 2021-09-10 00:00:00
# <Response [200]> 2021-09-11 00:00:00
# <Response [200]> 2021-09-12 00:00:00
# <Response [200]> 2021-09-13 00:00:00
# <Response [200]> 2021-09-14 00:00:00
# <Response [200]> 2021-09-15 00:00:00
# <Response [200]> 2021-09-16 00:00:00
# <Response [200]> 2021-09-17 00:00:00
# <Response [200]> 2021-09-18 00:00:00
# <Response [200]> 2021-09-19 00:00:00
# <Response [200]> 2021-09-20 00:00:00
# <Response [200]> 2021-09-21 00:00:00
# <Response [200]> 2021-09-22 00:00:00
# <Response [200]> 2021-09-23 00:00:00
# <Response [200]> 2021-09-24 00:00:00
# <Response [200]> 2021-09-25 00:00:00
# <Response [200]> 2021-09-26 00:00:00
# <Response [200]> 2021-09-27 00:00:00
# <Response [200]> 2021-09-28 00:00:00
# <Response [200]> 2021-09-29 00:00:00
# <Response [200]> 2021-09-30 00:00:00
# <Response [200]> 2021-10-01 00:00:00
# <Response [200]> 2021-10-02 00:00:00
# <Response [200]> 2021-10-03 00:00:00
# <Response [200]> 2021-10-04 00:00:00
# <Response [200]> 2021-10-05 00:00:00
# <Response [200]> 2021-10-06 00:00:00
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Inspiron G15\.conda\envs\IA_run\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Inspiron G15\.conda\envs\IA_run\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Inspiron G15\.conda\envs\IA_run\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\Inspiron G15\.conda\envs\IA_run\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 17
#      15 while '200' in str(resp_st):
#      16         resp_st = requests.get(url_conteo_vehiculos+ahora.strftime("%Y-%m-%d"), headers=Headers)
# ---> 17         response_cv = resp_st.json()
#      18         import pandas as pd
#      19         print(resp_st,ahora)
#
# File c:\Users\Inspiron G15\.conda\envs\IA_run\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df#.to_csv('route_RecaudoVehiculos.csv')
# Out:
#         estacion  sentido  hora categoria  valorTabulado       fecha
# 0          ANDES  BOG-CHI     0         I        3376100  2021-08-01
# 1          ANDES  BOG-CHI     1         I        2202200  2021-08-01
# 2          ANDES  BOG-CHI     2         I        1556100  2021-08-01
# 3          ANDES  BOG-CHI     3         I        1410500  2021-08-01
# 4          ANDES  BOG-CHI     4         I        2247700  2021-08-01
# ...          ...      ...   ...       ...            ...         ...
# 20355  UNISABANA  BOG-CHI    19       VII         149700  2021-10-06
# 20356  UNISABANA  BOG-CHI    20       VII         149700  2021-10-06
# 20357  UNISABANA  BOG-CHI    22       VII          49900  2021-10-06
# 20358      ANDES  BOG-CHI    18         I         218400  2021-10-06
# 20359      ANDES  BOG-CHI    23         I          45500  2021-10-06
#
# [20360 rows x 6 columns]
